# %% [markdown]
# # PhaseSentinel Model Training Notebook
#
# This notebook is for training the anomaly detection and regression models for PhaseSentinel.
#
# ## Models to Train:
#
# 1. **Anomaly Detection Model** (`anomaly_model.pkl`)
#    - Use Isolation Forest or similar anomaly detection algorithm
#    - Train on labeled simulation data from `data/training_data.csv`
#    - Save to `backend/models/anomaly_model.pkl`
#
# 2. **Optimization Regression Model** (`regression_model.pkl`)
#    - Use regression algorithm (Random Forest, Gradient Boosting, etc.)
#    - Train on `data/optimization_results.csv`
#    - Predict speedup based on metrics and phase type
#    - Save to `backend/models/regression_model.pkl`

# %%
# Example Training Code
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, RandomForestRegressor
import joblib
import os

print('Ready for model training')
